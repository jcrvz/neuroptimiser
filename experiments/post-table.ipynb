# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('batch_results/function_dimension_statistics.csv')
df["error_iqr"] = df["error_q75"] - df["error_q25"]

# %%
df.describe().T
# Out:
#                      count        mean          std           min  \
# function_id           27.0   13.111111     7.987169  1.000000e+00
# dimension             27.0    5.666667     3.362691  2.000000e+00
# n_instances           27.0   15.000000     0.000000  1.500000e+01
# best_fitness_mean     27.0  101.710925   354.099230 -1.463559e+02
# best_fitness_median   27.0   53.806911   217.415945 -4.715000e+01
# best_fitness_std      27.0  387.389882   320.281086  1.688412e+02
# best_fitness_min      27.0 -554.655671   267.115090 -1.000000e+03
# best_fitness_max      27.0  939.223369  1236.041821  1.142600e+02
# best_fitness_q25      27.0  -97.907446   142.094010 -2.779050e+02
# best_fitness_q75      27.0  248.677766   509.409320  3.680514e+01
# error_mean            27.0  105.996554   353.451331  1.793125e-10
# error_median          27.0   55.661557   218.231050  2.614797e-12
# error_std             27.0  111.155427   372.030026  4.347855e-10
# ...

# %%
# Select specific columns (replace with your desired columns)
selected_columns = ['function_id', 'dimension', 'error_mean', 'error_std', 'error_median', 'error_iqr', 'error_min', 'error_max', 'success_rate_1e-4']  # adjust as needed

# With additional formatting options
latex_table = df[selected_columns].to_latex(
    index=False,
    float_format=lambda x: f"{x:.3e}" if abs(x) < 1e-3 or abs(x) > 1e3 else f"{x:.3f}",
    escape=False,  # if you have LaTeX commands in your data
    caption="Your table caption",
    label="tab:your_label"
)

print(latex_table)
# Out:
# \begin{table}
# \caption{Your table caption}
# \label{tab:your_label}
# \begin{tabular}{rrrrrrrrr}
# \toprule
# function_id & dimension & error_mean & error_std & error_median & error_iqr & error_min & error_max & success_rate_1e-4 \\
# \midrule
# 1 & 2 & 1.568e-06 & 3.429e-06 & 1.135e-07 & 1.331e-06 & 0.000e+00 & 1.306e-05 & 100.000 \\
# 1 & 5 & 0.010 & 0.010 & 0.006 & 0.015 & 3.322e-04 & 0.032 & 0.000e+00 \\
# 1 & 10 & 0.142 & 0.080 & 0.115 & 0.079 & 0.051 & 0.303 & 0.000e+00 \\
# 2 & 2 & 2.937e-04 & 7.672e-04 & 1.463e-06 & 1.829e-04 & 0.000e+00 & 0.003 & 66.667 \\
# 2 & 5 & 55.127 & 56.613 & 51.302 & 52.919 & 1.008e-08 & 220.490 & 13.333 \\
# 2 & 10 & 1.508e+03 & 1.376e+03 & 1.128e+03 & 1.444e+03 & 7.626 & 5.269e+03 & 0.000e+00 \\
# 8 & 2 & 7.840e-05 & 2.010e-04 & 3.939e-06 & 4.095e-05 & 0.000e+00 & 7.830e-04 & 80.000 \\
# 8 & 5 & 2.545 & 1.623 & 2.331 & 1.742 & 0.287 & 6.671 & 0.000e+00 \\
# 8 & 10 & 27.964 & 35.394 & 13.401 & 11.761 & 7.481 & 126.515 & 0.000e+00 \\
# ...
